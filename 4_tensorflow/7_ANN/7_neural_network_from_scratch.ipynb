# %% [markdown]
# <h2 style="color:green" align="center">Implement Neural Network (or Logistic Regression) From Scratch</h2>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age','affordibility']],
                                                    df.bought_insurance,
                                                    test_size=0.2)

# %%
X_train_scaled = X_train.copy()
X_train_scaled['age'] = X_train_scaled['age'] / 100

X_test_scaled = X_test.copy()
X_test_scaled['age'] = X_test_scaled['age'] / 100

# %% [markdown]
# <img src="nn.jpg" height=800 width=800/>

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,),
                       activation='sigmoid',
                       kernel_initializer='ones',
                       bias_initializer='zeros')
])
model

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model

# %%
model.fit(X_train_scaled, y_train, epochs=500)#5000
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 694ms/step - loss: 0.7229 - accuracy: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7224 - accuracy: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7220 - accuracy: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7216 - accuracy: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7212 - accuracy: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7207 - accuracy: 0.5000
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7203 - accuracy: 0.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7199 - accuracy: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7195 - accuracy: 0.5000
# Epoch 10/500
# ...

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 1/1 [==============================] - 0s 149ms/step - loss: 0.6255 - accuracy: 0.6667
# [0.6254934072494507, 0.6666666865348816]

# %%
y_pred=model.predict(X_test_scaled)
y_pred
# Out:
# 1/1 [==============================] - 0s 98ms/step
# array([[0.44910318],
#        [0.45695528],
#        [0.44910318],
#        [0.6826653 ],
#        [0.6757611 ],
#        [0.6216819 ]], dtype=float32)

# %%
coef, intercept = model.get_weights()

# %%
coef, intercept
# Out:
# (array([[0.79221886],
#         [0.67722154]], dtype=float32),
#  array([-0.4023496], dtype=float32))

# %% [markdown]
# **Instead of model.predict, write our own prediction function that uses w1,w2 and bias**

# %%
def mysigmoid(x):
        import math
        return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age, affordibility):
    weighted_sum = coef[0]*age + coef[1]*affordibility + intercept
    return mysigmoid(weighted_sum)

# %%
prediction_function(18, 1)
# Out:
# 0.9999995129073603

# %%
if prediction_function(18,1) >=0.5:
    print(1)
else:
    print(0)
# Out:
# 1

# %% [markdown]
# # :: Manual ANN Code ::

# %%
def sigmoid_numpy(X):
   return 1/(1+np.exp(-X))

# %%
def log_loss(y_true, y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
class myNN:
    def __init__(self):
        self.w1 = 1 
        self.w2 = 1
        self.bias = 0
        
    def fit(self, X, y, epochs, loss_thresold):
        self.w1, self.w2,self.bias =self.gradient_descent(X['age'],
                                         X['affordibility'],
                                         y,epochs, loss_thresold)
        print(f"Final weights and bias: w1: {self.w1}, w2: {self.w2},bias: {self.bias}")
        
    def predict(self, X_test):
        weighted_sum = self.w1*X_test['age'] +\
              self.w2*X_test['affordibility'] + self.bias
        return sigmoid_numpy(weighted_sum)

    def gradient_descent(self, age,affordability, y_true, epochs,loss_thresold):
        w1 = w2 = 1
        bias = 0
        rate = 0.5
        n = len(age)
        for i in range(epochs):
            weighted_sum = w1 * age + w2 * affordability + bias
            y_predicted = sigmoid_numpy(weighted_sum)
            loss = log_loss(y_true, y_predicted)
            
            w1d = (1/n)*np.dot(np.transpose(age),
                               (y_predicted-y_true)) 
            w2d = (1/n)*np.dot(np.transpose(affordability),
                               (y_predicted-y_true)) 

            bias_d = np.mean(y_predicted-y_true)
            w1 = w1 - rate * w1d
            w2 = w2 - rate * w2d
            bias = bias - rate * bias_d
            
            if i%50==0:
                print (f'% i Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias},loss:{loss}')
            
            if loss<=loss_thresold:
                print (f'loss Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
                break

        return w1, w2, bias

# %%
customModel = myNN()
customModel

# %%
vvv=800#8000
customModel.fit(X_train_scaled, y_train, epochs=vvv, loss_thresold=0.4631)
# Out:
# % i Epoch:0, w1:0.9746936884392039, w2:0.9355414162805802, bias:-0.12323191277535987,loss:0.7228670678688007
# % i Epoch:50, w1:1.6292731150228381, w2:1.1572401152686178, bias:-1.396451984775074,loss:0.5434024749171878
# % i Epoch:100, w1:2.457501433729953, w2:1.4566780781012862, bias:-1.9847007295376597,loss:0.49812714209428405
# % i Epoch:150, w1:3.2401539898124248, w2:1.6353301948732637, bias:-2.4542133976249048,loss:0.46335874949859907
# loss Epoch:151, w1:3.2552495926473672, w2:1.6382100539944409, bias:-2.462793872577338, loss:0.46273726629051504
# Final weights and bias: w1: 3.2552495926473672, w2: 1.6382100539944409,bias: -2.462793872577338

# %%
customModel.w1,customModel.w2,customModel.bias
# Out:
# (3.2552495926473672, 1.6382100539944409, -2.462793872577338)

# %%
customModel.predict(X_test_scaled)
# Out:
# 16    0.161247
# 13    0.179642
# 1     0.161247
# 8     0.767397
# 17    0.743351
# 11    0.521708
# dtype: float64
