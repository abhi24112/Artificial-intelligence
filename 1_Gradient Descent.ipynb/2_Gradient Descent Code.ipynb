# %% [markdown]
# <h1 style = "font-size:3rem;color:orange;">Implementation Of Gradient Descent</h1>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
def gradient_descent(x,y):
    
    # we have to select any initial value to start the process
    m_curr = b_curr = 0 
    iteration = 1000
    learning_rate = 0.06 # Learning Rate(α)alpha (we have to do hit and trial to find LR)
    
    for i in range(iteration):
        # predicted value of (y)
        y_pre = m_curr * x + b_curr
        
        #cost function (mse)
        cost = (1/n) * sum((y-y_pre)**2)

        # partial differentiation of (mse) with resp. of (m) and (b)
        md = -(2/n) * sum(x*(y-y_pre))
        bd = -(2/n) * sum((y-y_pre))

        # Learning Rate 
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print(f"m:{m_curr} b:{b_curr} cost:{cost} iteration:{i+1}")

# Driver code
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
n = len(x)

#function Calling
gradient_descent(x,y)
# Out:
# m:3.7199999999999998 b:1.08 cost:89.0 iteration:1
# m:2.1408000000000005 b:0.6912 cost:16.414399999999997 iteration:2
# m:2.7861119999999997 b:0.9175679999999998 cost:3.598154239999994 iteration:3
# m:2.4981196800000003 b:0.8844595199999999 cost:1.3120671703039974 iteration:4
# m:2.6021962752 b:0.9590012927999998 cost:0.8821128126070779 iteration:5
# m:2.542056726528 b:0.9871304785919999 cost:0.7802287003212346 iteration:6
# m:2.55117487521792 b:1.03353439961088 cost:0.7371873705156168 iteration:7
# m:2.531551656070349 b:1.071087316579123 cost:0.7055195398112968 iteration:8
# m:2.5243120360890043 b:1.1111982424043028 cost:0.6768225463195567 iteration:9
# m:2.5121887811859698 b:1.1491021203237448 cost:0.649577330801426 iteration:10
# m:2.5024228267039414 b:1.1868219046579462 cost:0.6234790097440573 iteration:11
# m:2.491968809777878 b:1.2235310584855736 cost:0.5984380862766648 iteration:12
# m:2.4820987998162725 b:1.2595985599472688 cost:0.5744044433169527 iteration:13
# ...

# %%
# optimize value of m:2.000000000791095
# optimize value of b:2.9999999971438953

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descent(x, y):
#     m_curr = b_curr = 0
#     rate = 0.08
#     n = len(x)
#     plt.figure(figsize=(8, 6))
#     plt.scatter(x, y, color='red', marker='+', s=100, label='Data Points')  # 's' is for size, not 'linewidth'
  
#     for i in range(100):
#         # Predict values
#         y_predicted = m_curr * x + b_curr
        
#         # Plot the current line
#         if i == 0:
#             plt.plot(x, y_predicted, color='green', label='Fit Line')
#         else:
#             plt.plot(x, y_predicted, color='green')
        
#         md = -(2/n) * np.sum(x * (y - y_predicted))
#         yd = -(2/n) * np.sum(y - y_predicted)
        
#         m_curr -= rate * md
#         b_curr -= rate * yd

#         cost = np.mean((y - y_predicted) ** 2)
        # print(f"Iteration {i+1}: m = {m_curr}, b = {b_curr}, cost = {cost}")  


            # we have to select any initial value to start the process
    m_curr = b_curr = 0 
    iteration = 1000
    n = len(x)
    learning_rate = 0.06 # Learning Rate(α)alpha (we have to do hit and trial to find LR)
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, color='red', marker='*', s=100, label='Data Points')
    for i in range(iteration):
        # predicted value of (y)
        y_pre = m_curr * x + b_curr
        # Plot the current line
        if i == 0:
            plt.plot(x, y_pre, color='green', label='Fit Line')
        elif i == iteration-1:
            plt.plot(x, y_pre, color='red',linewidth=2, label='Best Fit Line') # optimized m and b
            print(f"m:{m_curr} b:{b_curr} cost:{cost} iteration:{i+1}")
            
        else:
            plt.plot(x,y_pre, color='green')
        #cost function (mse)
        cost = (1/n) * sum((y-y_pre)**2)

        # partial differentiation of (mse) with resp. of (m) and (b)
        md = -(2/n) * sum(x*(y-y_pre))
        bd = -(2/n) * sum((y-y_pre))

        # Learning Rate 
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        # print(f"m:{m_curr} b:{b_curr} cost:{cost} iteration:{i+1}")
        
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Gradient Descent Visualization')
    plt.grid()
    plt.legend()
    plt.show()
    
# Example data
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 9, 11, 13])
gradient_descent(x, y)
# Out:
# m:2.0000000008074754 b:2.9999999970847573 cost:1.6116230912506808e-18 iteration:1000
